# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras import layers, models
import numpy as np

# Load IMDB dataset
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

# Function to vectorize sequences
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Vectorizing training data
train_data = vectorize_sequences(train_data)

# Build the model
model = models.Sequential([
    layers.Dense(16, activation="relu"),
    layers.Dense(16, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Train the model
history_original = model.fit(train_data, train_labels,
                             epochs=20,
                             batch_size=512,
                             validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7068 - loss: 0.6005 - val_accuracy: 0.8517 - val_loss: 0.4148
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8914 - loss: 0.3516 - val_accuracy: 0.8756 - val_loss: 0.3321
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9167 - loss: 0.2613 - val_accuracy: 0.8897 - val_loss: 0.2882
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9326 - loss: 0.2094 - val_accuracy: 0.8896 - val_loss: 0.2782
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9433 - loss: 0.1754 - val_accuracy: 0.8870 - val_loss: 0.2827
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9541 - loss: 0.1498 - val_accuracy: 0.8837 - val_loss: 0.2917
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9603 - loss: 0.1295 - val_accuracy: 0.8755 - val_loss: 0.3234
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9686 - loss: 0.1093 - val_accuracy: 0.8810 - val_loss: 0.3160
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.0955 - val_accuracy: 0.8840 - val_loss: 0.3170
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9762 - loss: 0.0862 - val_accuracy: 0.8729 - val_loss: 0.3645
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9819 - loss: 0.0755 - val_accuracy: 0.8764 - val_loss: 0.3506
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9819 - loss: 0.0685 - val_accuracy: 0.8802 - val_loss: 0.3637
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9869 - loss: 0.0576 - val_accuracy: 0.8726 - val_loss: 0.3916
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0508 - val_accuracy: 0.8765 - val_loss: 0.3998
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9910 - loss: 0.0450 - val_accuracy: 0.8694 - val_loss: 0.4597
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9923 - loss: 0.0419 - val_accuracy: 0.8747 - val_loss: 0.4405
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9956 - loss: 0.0302 - val_accuracy: 0.8711 - val_loss: 0.4626
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9951 - loss: 0.0303 - val_accuracy: 0.8700 - val_loss: 0.5050
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9966 - loss: 0.0249 - val_accuracy: 0.8668 - val_loss: 0.5176
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9971 - loss: 0.0225 - val_accuracy: 0.8705 - val_loss: 0.5273

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras import layers, models
import numpy as np

# Load IMDB dataset
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

# Function to vectorize sequences
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Vectorizing training data
train_data = vectorize_sequences(train_data)

# Build the model
model = models.Sequential([
    layers.Dense(4, activation="relu"),
    layers.Dense(4, activation="relu"),
    layers.Dense(1, activation="sigmoid")
])

# Compile the model
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Train the model
history_original = model.fit(train_data, train_labels,
                             epochs=20,
                             batch_size=512,
                             validation_split=0.4)
# Out:
# Epoch 1/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5773 - loss: 0.6538 - val_accuracy: 0.7675 - val_loss: 0.5705
# Epoch 2/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7807 - loss: 0.5461 - val_accuracy: 0.7931 - val_loss: 0.5209
# Epoch 3/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8403 - loss: 0.4926 - val_accuracy: 0.8139 - val_loss: 0.4924
# Epoch 4/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8757 - loss: 0.4524 - val_accuracy: 0.8538 - val_loss: 0.4676
# Epoch 5/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9044 - loss: 0.4249 - val_accuracy: 0.8489 - val_loss: 0.4546
# Epoch 6/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9163 - loss: 0.4000 - val_accuracy: 0.8767 - val_loss: 0.4347
# Epoch 7/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9329 - loss: 0.3742 - val_accuracy: 0.8853 - val_loss: 0.4221
# Epoch 8/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9465 - loss: 0.3548 - val_accuracy: 0.8690 - val_loss: 0.4196
# Epoch 9/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9518 - loss: 0.3352 - val_accuracy: 0.8734 - val_loss: 0.4106
# Epoch 10/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9596 - loss: 0.3132 - val_accuracy: 0.8819 - val_loss: 0.3957
# Epoch 11/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9644 - loss: 0.2960 - val_accuracy: 0.8561 - val_loss: 0.4274
# Epoch 12/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9656 - loss: 0.2835 - val_accuracy: 0.8796 - val_loss: 0.3897
# Epoch 13/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9753 - loss: 0.2640 - val_accuracy: 0.8811 - val_loss: 0.3807
# Epoch 14/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9748 - loss: 0.2488 - val_accuracy: 0.8789 - val_loss: 0.3841
# Epoch 15/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9798 - loss: 0.2323 - val_accuracy: 0.8779 - val_loss: 0.3804
# Epoch 16/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9814 - loss: 0.2164 - val_accuracy: 0.8770 - val_loss: 0.3869
# Epoch 17/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.2029 - val_accuracy: 0.8761 - val_loss: 0.3862
# Epoch 18/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9837 - loss: 0.1944 - val_accuracy: 0.8726 - val_loss: 0.4011
# Epoch 19/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.1814 - val_accuracy: 0.8726 - val_loss: 0.3996
# Epoch 20/20
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9876 - loss: 0.1695 - val_accuracy: 0.8691 - val_loss: 0.4188

# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras import layers, models
import numpy as np

# Load IMDB dataset
(train_data, train_labels), _ = imdb.load_data(num_words=10000)

# Function to vectorize sequences
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Vectorizing training data
train_data = vectorize_sequences(train_data)

# Build the model
model = models.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(512, activation="relu"),
    layers.Dense(512, activation="sigmoid")
])

# Compile the model
model.compile(optimizer="rmsprop",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# Train the model
history_original = model.fit(train_data, train_labels,
                             epochs=20,
                             batch_size=512,
                             validation_split=0.4)
# Out:
# Epoch 1/20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 31
#      26 model.compile(optimizer="rmsprop",
#      27               loss="binary_crossentropy",
#      28               metrics=["accuracy"])
#      30 # Train the model
# ---> 31 history_original = model.fit(train_data, train_labels,
#      32                              epochs=20,
#      33                              batch_size=512,
#      34                              validation_split=0.4)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:694, in binary_crossentropy(target, output, from_logits)
#     691 output = tf.convert_to_tensor(output)
#     693 if len(target.shape) != len(output.shape):
# --> 694     raise ValueError(
#     695         "Arguments `target` and `output` must have the same rank "
#     696         "(ndim). Received: "
#     697         f"target.shape={target.shape}, output.shape={output.shape}"
#     698     )
#     699 for e1, e2 in zip(target.shape, output.shape):
#     700     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(None,), output.shape=(None, 512)
